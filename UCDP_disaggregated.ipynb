# %%
import pandas as pd
ucdp_dis = pd.read_csv("GEDEvent_v26_0_4.csv")
ucdp_dis.head()
# Out:
#        id                relid  year  active_year code_status  \
# 0  625373  IRN-2026-1-18868-62  2026         True       Clear
# 1  626545   ISR-2026-1-477-234  2026         True       Clear
# 2  626547   ISR-2026-1-18806-0  2026        False       Clear
# 3  626551   ISR-2026-1-891-241  2026         True       Clear
# 4  626555   ISR-2026-1-477-236  2026         True       Clear
#
#    type_of_violence conflict_dset_id  conflict_new_id  \
# 0                 1              NaN            16905
# 1                 1              234              234
# 2                 1              234              234
# 3                 1              426              426
# 4                 1              234              234
#
#                              conflict_name dyad_dset_id  ...  \
# 0  Iran - Israel, United States of America        18868  ...
# 1                        Israel: Palestine          477  ...
# 2                        Israel: Palestine        18806  ...
# ...

# %%
unique_conflicts = ucdp_dis['conflict_name'].dropna().unique()
print('total number:', len(unique_conflicts))
print(sorted(unique_conflicts))
# Out:
# total number: 182
# ...
